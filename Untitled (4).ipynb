# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.3     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
df = read_csv(
    'https://raw.githubusercontent.com/fivethirtyeight/data/master/bechdel/movies.csv')
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   year = col_double(),
#   imdb = col_character(),
#   title = col_character(),
#   test = col_character(),
#   clean_test = col_character(),
#   binary = col_character(),
#   budget = col_double(),
#   domgross = col_character(),
#   intgross = col_character(),
#   code = col_character(),
#   `budget_2013$` = col_double(),
#   `domgross_2013$` = col_character(),
#   `intgross_2013$` = col_character(),
#   `period code` = col_double(),
#   `decade code` = col_double()
# )

# %%
clean = df%>%
filter(!grepl('#N/A', `intgross_2013$`))%>%
filter(!grepl('#N/A', `domgross_2013$`))%>%
group_by(year)%>%
mutate(adjdom = `domgross_2013$`, adjint = `intgross_2013$`, adjbudget = `budget_2013$`)%>%
mutate(adjbudget = as.numeric(adjbudget))%>%
mutate(adjdom = as.numeric(adjdom)) %>%
mutate(adjint = as.numeric(adjint))%>%
mutate(wwgross = adjdom + adjint) %>%
mutate(roi = wwgross/adjbudget)%>%
select(year, title, binary, adjbudget, wwgross, roi) %>%
filter(roi>1)%>%
arrange(year)%>%
mutate(filmsperyear = n())%>%
mutate(Decade = year%/% 10 * 10)%>%
group_by(Decade)%>%
mutate(filmsperdecade = n())
clean
# Out:
#      year title                                   binary adjbudget wwgross
# 1    1970 Beyond the Valley of the Dolls          PASS     5997631  107957366
# 2    1971 Escape from the Planet of the Apes      FAIL    14386286  141561050
# 3    1971 Shaft                                   FAIL   305063707 1021529721
# 4    1971 The French Connection                   FAIL    12659931  473697306
# 5    1971 Willy Wonka &amp; the Chocolate Factory FAIL    17263543   46036114
# 6    1972 Pink Flamingos                          PASS       66866    4611524
# 7    1972 The Godfather                           FAIL    39004975 2248171046
# 8    1973 American Graffiti                       FAIL     4074506 1337193022
# 9    1973 High Plains Drifter                     FAIL    82329139  164658278
# 10   1973 Sleeper                                 FAIL    10487788  192395636
# 11   1973 The Exorcist                            PASS    62926730 3186206563
# 12   1973 The Sting                               FAIL    28841418 1674022264
# 13   1974 Black Christmas                         PASS    42513535  153386358
# 14   1974 Blazing Saddles                         FAIL    12281688 1128970538
# 15   1974 The Conversation                        FAIL     7557962   41757738
# 16   1974 The Godfather: Part II                  PASS    61408439  541339010
# 17   1974 The Texas Chain Saw Massacre            FAIL      661322  251041848
# 18   1974 The Towering Inferno                    FAIL      661322  251041848
# 19   1974 Young Frankenstein                      FAIL    13226433  815315124
# 20   1975 Barry Lyndon                            FAIL    47609104  173124014
# 21   1975 Jaws                                    FAIL    51937204 3162542908
# 22   1975 Monty Python and the Holy Grail         FAIL     1731240   36601203
# 23   1975 One Flew Over the Cuckoo&#39;s Nest     FAIL    19043641  943363784
# 24   1975 The Rocky Horror Picture Show           FAIL     5193720 1210798332
# 25   1976 Assault on Precinct 13                  FAIL   122754817  229476996
# 26   1976 Family Plot                             PASS    12275482  108024240
# 27   1976 Logan&#39;s Run                         FAIL    28642791  204591362
# 28   1976 Network                                 PASS    15548943  193869768
# 29   1976 Rocky                                   FAIL     4091827 1400367095
# 30   1976 Silent Movie                            FAIL    18004040  295803878
# ⋮    ⋮    ⋮                                       ⋮      ⋮         ⋮
# 1578 2013 The Conjuring                           PASS   2.00e+07   455400282
# 1579 2013 The Counselor                           PASS   2.50e+07    87347430
# 1580 2013 The Croods                              FAIL   1.35e+08   760236850
# 1581 2013 The Family                              FAIL   3.00e+07    87997352
# 1582 2013 The Great Gatsby                        FAIL   1.90e+08   495880838
# 1583 2013 The Hangover part 3                     FAIL   1.03e+08   474200144
# 1584 2013 The Heat                                PASS   4.30e+07   390363174
# 1585 2013 The Hobbit: The Desolation of Smaug     FAIL   2.50e+08  1194795032
# 1586 2013 The Host                                FAIL   5.00e+07    84812085
# 1587 2013 The Hunger Games: Catching Fire         PASS   1.30e+08  1281176520
# 1588 2013 The Incredible Burt Wonderstone         FAIL   3.20e+07    46793838
# 1589 2013 The Internship                          FAIL   5.80e+07   138345528
# 1590 2013 The Last Exorcism Part II               PASS   4.00e+06    33720539
# 1591 2013 The Lone Ranger                         FAIL   2.75e+08   349279820
# 1592 2013 The Mortal Instruments: City of Bones   PASS   6.00e+07   107130988
# 1593 2013 The Purge                               FAIL   3.00e+06   155573656
# 1594 2013 The Smurfs 2                            PASS   1.10e+08   419563625
# 1595 2013 The To Do List                          PASS   1.50e+06     6983338
# 1596 2013 The Way Way Back                        PASS   5.00e+06    47664133
# 1597 2013 The Wolf of Wall Street                 FAIL   1.00e+08   481405714
# 1598 2013 The Wolverine                           PASS   1.15e+08   549013704
# 1599 2013 The World&#39;s End                     FAIL   2.00e+07    72583672
# 1600 2013 This Is the End                         FAIL   3.20e+07   227764466
# 1601 2013 Thor: The Dark World                    FAIL   1.70e+08   836349580
# 1602 2013 Trance                                  FAIL   1.60e+07    24916645
# 1603 2013 Turbo                                   FAIL   1.35e+08   366856260
# 1604 2013 Warm Bodies                             FAIL   3.00e+07   183024272
# 1605 2013 We&#39;re the Millers                   PASS   3.70e+07   420394238
# 1606 2013 White House Down                        FAIL   1.50e+08   278544171
# 1607 2013 World War Z                             FAIL   1.90e+08   741919422
#      roi        filmsperyear Decade filmsperdecade
# 1     18.000001 1            1970   50
# 2      9.840000 4            1970   50
# 3      3.348578 4            1970   50
# 4     37.417053 4            1970   50
# 5      2.666667 4            1970   50
# 6     68.966650 2            1970   50
# 7     57.638059 2            1970   50
# 8    328.185312 5            1970   50
# 9      2.000000 5            1970   50
# 10    18.344730 5            1970   50
# 11    50.633595 5            1970   50
# 12    58.042301 5            1970   50
# 13     3.607942 7            1970   50
# 14    91.923076 7            1970   50
# 15     5.525000 7            1970   50
# 16     8.815385 7            1970   50
# 17   379.606074 7            1970   50
# 18   379.606074 7            1970   50
# 19    61.642857 7            1970   50
# 20     3.636364 5            1970   50
# 21    60.891667 5            1970   50
# 22    21.141611 5            1970   50
# 23    49.536944 5            1970   50
# 24   233.127379 5            1970   50
# 25     1.869393 8            1970   50
# 26     8.800000 8            1970   50
# 27     7.142857 8            1970   50
# 28    12.468357 8            1970   50
# 29   342.235167 8            1970   50
# 30    16.429861 8            1970   50
# ⋮    ⋮          ⋮            ⋮      ⋮
# 1578 22.770014  94           2010   396
# 1579  3.493897  94           2010   396
# 1580  5.631384  94           2010   396
# 1581  2.933245  94           2010   396
# 1582  2.609899  94           2010   396
# 1583  4.603885  94           2010   396
# 1584  9.078213  94           2010   396
# 1585  4.779180  94           2010   396
# 1586  1.696242  94           2010   396
# 1587  9.855204  94           2010   396
# 1588  1.462307  94           2010   396
# 1589  2.385268  94           2010   396
# 1590  8.430135  94           2010   396
# 1591  1.270108  94           2010   396
# 1592  1.785516  94           2010   396
# 1593 51.857885  94           2010   396
# 1594  3.814215  94           2010   396
# 1595  4.655559  94           2010   396
# 1596  9.532827  94           2010   396
# 1597  4.814057  94           2010   396
# 1598  4.774032  94           2010   396
# 1599  3.629184  94           2010   396
# 1600  7.117640  94           2010   396
# 1601  4.919703  94           2010   396
# 1602  1.557290  94           2010   396
# 1603  2.717454  94           2010   396
# 1604  6.100809  94           2010   396
# 1605 11.362006  94           2010   396
# 1606  1.856961  94           2010   396
# 1607  3.904839  94           2010   396

# %%
bar = clean %>%
group_by(Decade, binary)%>%
count(filmsperdecade)
bar
# Out:
#    Decade binary filmsperdecade n
# 1  1970   FAIL    50             37
# 2  1970   PASS    50             13
# 3  1980   FAIL   115             84
# 4  1980   PASS   115             31
# 5  1990   FAIL   305            170
# 6  1990   PASS   305            135
# 7  2000   FAIL   741            374
# 8  2000   PASS   741            367
# 9  2010   FAIL   396            220
# 10 2010   PASS   396            176

# %%
p = ggplot(bar, aes(x = Decade, y = n, color = binary))

p = p + geom_col()

p
# Out:
# plot without title

# %%
p = ggplot(clean, aes(x = roi, y = year, color = binary))

p = p + geom_point(position = position_jitter(w=5, h=0))

p = p + geom_smooth()

p = p + facet_wrap(~Decade)

p
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
# new = clean %>% 
#   select(title, binary, year)%>%
#   group_by(year, binary) %>%
#   summarize(n = n()) %>%
#   mutate(percentage = n/sum(n)*100)


# df2 = new %>%
# left_join(clean)

df3 = clean %>%
group_by(binary, year)%>%
summarize(medroi = median(roi))

df4 = df3 %>%
left_join(clean)
df4

# ecdf = clean %>%
#     arrange(binary) %>%
#     group_by(year) %>%
#     mutate(rn = row_number(), fraction_of_movies = rn / max(rn))
# Out:
# `summarise()` has grouped output by 'binary'. You can override using the `.groups` argument.
#
# Joining, by = c("binary", "year")
#      binary year medroi    title                                   adjbudget
# 1    FAIL   1971  6.594289 Escape from the Planet of the Apes       14386286
# 2    FAIL   1971  6.594289 Shaft                                   305063707
# 3    FAIL   1971  6.594289 The French Connection                    12659931
# 4    FAIL   1971  6.594289 Willy Wonka &amp; the Chocolate Factory  17263543
# 5    FAIL   1972 57.638059 The Godfather                            39004975
# 6    FAIL   1973 38.193515 American Graffiti                         4074506
# 7    FAIL   1973 38.193515 High Plains Drifter                      82329139
# 8    FAIL   1973 38.193515 Sleeper                                  10487788
# 9    FAIL   1973 38.193515 The Sting                                28841418
# 10   FAIL   1974 91.923076 Blazing Saddles                          12281688
# 11   FAIL   1974 91.923076 The Conversation                          7557962
# 12   FAIL   1974 91.923076 The Texas Chain Saw Massacre               661322
# 1607 PASS   2013 4.389003  We&#39;re the Millers                   3.70e+07
#      wwgross    roi        filmsperyear Decade filmsperdecade
# 1     141561050   9.840000 4            1970   50
# 2    1021529721   3.348578 4            1970   50
# 3     473697306  37.417053 4            1970   50
# 4      46036114   2.666667 4            1970   50
# 5    2248171046  57.638059 2            1970   50
# 6    1337193022 328.185312 5            1970   50
# 7     164658278   2.000000 5            1970   50
# 8     192395636  18.344730 5            1970   50
# 9    1674022264  58.042301 5            1970   50
# 10   1128970538  91.923076 7            1970   50
# 11     41757738   5.525000 7            1970   50
# 12    251041848 379.606074 7            1970   50
# 13    251041848 379.606074 7            1970   50
# 14    815315124  61.642857 7            1970   50
# 15    173124014   3.636364 5            1970   50
# 16   3162542908  60.891667 5            1970   50
# 17     36601203  21.141611 5            1970   50
# 18    943363784  49.536944 5            1970   50
# 19   1210798332 233.127379 5            1970   50
# 20    229476996   1.869393 8            1970   50
# 21    204591362   7.142857 8            1970   50
# 22   1400367095 342.235167 8            1970   50
# 23    295803878  16.429861 8            1970   50
# 24    231291140  56.525151 8            1970   50
# 25    390463666   3.907692 6            1970   50
# 26   1935792798  25.185000 6            1970   50
# 27     53804048 139.999865 6            1970   50
# 28    238759600  18.272376 6            1970   50
# 29   4838129232 114.445275 6            1970   50
# 30   1011223936  94.400000 7            1970   50
# ⋮    ⋮          ⋮          ⋮            ⋮      ⋮
# 1578  281406950  5.628139  94           2010   396
# 1579   89635182  3.201256  94           2010   396
# 1580  268145524  8.938184  94           2010   396
# 1581   17416322  8.708161  94           2010   396
# 1582  219669433 14.644629  94           2010   396
# 1583  979045036  4.351311  94           2010   396
# 1584   34965034  2.913753  94           2010   396
# 1585  724341992  3.621710  94           2010   396
# 1586   63963292  1.827523  94           2010   396
# 1587  269419108  2.993546  94           2010   396
# 1588  174404604  3.791404  94           2010   396
# 1589  190425120  2.266966  94           2010   396
# 1590  165342743  5.905098  94           2010   396
# 1591  183568664  5.244819  94           2010   396
# 1592   92461120  3.082037  94           2010   396
# 1593   73435262  3.671763  94           2010   396
# 1594   57590069  1.772002  94           2010   396
# 1595   83391050  4.389003  94           2010   396
# 1596  110811146  8.523934  94           2010   396
# 1597  455400282 22.770014  94           2010   396
# 1598   87347430  3.493897  94           2010   396
# 1599  390363174  9.078213  94           2010   396
# 1600 1281176520  9.855204  94           2010   396
# 1601   33720539  8.430135  94           2010   396
# 1602  107130988  1.785516  94           2010   396
# 1603  419563625  3.814215  94           2010   396
# 1604    6983338  4.655559  94           2010   396
# 1605   47664133  9.532827  94           2010   396
# 1606  549013704  4.774032  94           2010   396
# 1607  420394238 11.362006  94           2010   396

# %%
p = ggplot(df2, aes(x = filmsperdecade, y = n, group = binary, color = binary))
p = p + geom_line() + geom_point(size = 0.5)
p = p + facet_wrap(~Decade)
p
# Out:
# plot without title

# %%
p = ggplot(df4, aes(x = year, y = medroi, group = binary, color = binary))
p = p + geom_line(alpha = 0.5)
#p = p + facet_wrap(~binary)
p
# Out:
# plot without title

# %%
options(repr.plot.width=15, repr.plot.height=8, repr.plot.res = 300)
